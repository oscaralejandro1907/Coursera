# %% [markdown]
# # Logistic Regression

# %% [markdown]
# Performed when you have a categorical Y variable and a numerical X variable

# %% [markdown]
# Steps:<br>
# 1. Enter data in event/trial format
# 2. Make a fitted line plot
# 3. $p$-value

# %%
df<-read.csv("Callcenter-Table 1.csv",
               header = TRUE,
               sep = ",",
               stringsAsFactors = FALSE,
               skip = 11) [ ,5:6]
df
# Out:
#     HoldTime.1 HungUp.1
# 1   16         0
# 2   10         0
# 3   19         1
# 4   12         0
# 5   19         1
# 6    6         1
# 7   17         0
# 8   17         0
# 9    5         0
# 10   6         0
# 11  15         1
# 12  12         1
# 13  15         1
# 14  20         1
# 15  13         1
# 16  12         0
# 17   1         0
# 18  14         0
# 19   7         0
# 20  16         1
# 21  16         1
# 22   2         0
# 23   7         0
# 24  20         1
# 25   3         0
# 26   8         0
# 27   7         1
# 28  15         1
# 29  19         1
# 30   2         0
# ⋮   ⋮          ⋮
# 307  3         0
# 308  9         0
# 309 16         0
# 310  5         1
# 311  4         1
# 312 10         0
# 313 15         1
# 314  6         0
# 315 19         1
# 316  5         0
# 317 11         0
# 318 11         1
# 319 16         1
# 320  1         0
# 321 15         1
# 322  8         1
# 323 16         1
# 324  2         0
# 325 18         1
# 326 19         1
# ...

# %%
logitMod <- glm(df$HungUp.1 ~ df$HoldTime.1  ,data = df, family = binomial(link='logit'))
summary(logitMod)
# Out:
# Call:
# glm(formula = df$HungUp.1 ~ df$HoldTime.1, family = binomial(link = "logit"),
#     data = df)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.1411  -0.8226   0.4616   0.7932   2.2048
#
# Coefficients:
#               Estimate Std. Error z value Pr(>|z|)
# (Intercept)   -2.57648    0.32293  -7.978 1.48e-15 ***
# df$HoldTime.1  0.23811    0.02668   8.924  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 465.69  on 335  degrees of freedom
# Residual deviance: 353.76  on 334  degrees of freedom
# AIC: 357.76
#
# Number of Fisher Scoring iterations: 4

# %% [markdown]
# As the $p$-value is less than $0.05$ indicates the relation between holding time and the probability of hung up or not is significant.

# %% [markdown]
# The standard logistic regression function, for predicting the outcome of an observation given a predictor variable (x), is an s-shaped curve defined as p = $exp(y) / [1 + exp(y)]$. This can be also simply written as p = 1/[1 + exp(-y)].

# %% [markdown]
# ## Student Exercise

# %%
students<-read.csv("Student-Table 1.csv",
               header = TRUE,
               sep = ",",
               stringsAsFactors = FALSE,
               skip = 6) [ ,1:3]
students
# Out:
#    Student Math.grade Pass.
# 1   1      7          No
# 2   2      7          Yes
# 3   3      *          No
# 4   4      8          No
# 5   5      8          Yes
# 6   6      9          No
# 7   7      9          No
# 8   8      5          No
# 9   9      7          No
# 10 10      9          Yes
# 11 11      8          No
# 12 12      10         Yes
# 13 13      10         Yes
# 14 14      *          No
# 15 15      6          No
# 16 16      9          Yes
# 17 17      9          Yes
# 18 18      6          No
# 19 19      *          No
# 20 20      8          Yes
# 21 21      8          No
# 22 22      7          No
# 23 23      7          No
# 24 24      *          No
# 25 25      6          No
# 26 26      6          No
# 27 27      10         Yes
# 28 28      *          No
# 29 29      8          Yes
# 30 30      9          Yes

# %% [markdown]
# The Y-variable is whether or not the student passed their first year (categorical), and <br>
# The X- variable is the final grade that students received in high school for math(numerical).

# %%
#Clean the data
students <- transform(students, Math.grade = as.numeric(students$Math.grade)) #To create NA make numeric first
students<-students[complete.cases(students), ]
students
# Out:
#    Student Math.grade Pass.
# 1   1       7         0
# 2   2       7         1
# 4   4       8         0
# 5   5       8         1
# 6   6       9         0
# 7   7       9         0
# 8   8       5         0
# 9   9       7         0
# 10 10       9         1
# 11 11       8         0
# 12 12      10         1
# 13 13      10         1
# 15 15       6         0
# 16 16       9         1
# 17 17       9         1
# 18 18       6         0
# 20 20       8         1
# 21 21       8         0
# 22 22       7         0
# 23 23       7         0
# 25 25       6         0
# 26 26       6         0
# 27 27      10         1
# 29 29       8         1
# 30 30       9         1

# %%
students$Pass. <-ifelse(students$Pass.=="Yes",1,0)

# %%
logitM <- glm(students$Pass ~ students$Math.grade ,data = students, family = binomial(link='logit'))
summary(logitM)
# Out:
# Call:
# glm(formula = students$Pass ~ students$Math.grade, family = binomial(link = "logit"),
#     data = students)
#
# Deviance Residuals:
#        Min          1Q      Median          3Q         Max
# -3.971e-06  -3.971e-06  -3.971e-06  -3.971e-06  -3.971e-06
#
# Coefficients:
#                       Estimate Std. Error z value Pr(>|z|)
# (Intercept)         -2.557e+01  2.498e+05       0        1
# students$Math.grade  1.613e-15  3.139e+04       0        1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 0.0000e+00  on 24  degrees of freedom
# Residual deviance: 3.9425e-10  on 23  degrees of freedom
# AIC: 4
#
# Number of Fisher Scoring iterations: 24
